# %%
# import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# to ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('datasets\\StudentsPerformance.csv')
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
# check the data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
# check missing values
df.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
# check duplicates
df.duplicated().sum()
# Out:
# 0

# %%
# check unique values
df.nunique()
# Out:
# gender                          2
# race/ethnicity                  5
# parental level of education     6
# lunch                           2
# test preparation course         2
# math score                     81
# reading score                  72
# writing score                  77
# dtype: int64

# %%
# check statistics of dataset
df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
# Adding Columns for 'Total Score' and 'Average Score'
df['total score'] = df['math score']+df['reading score']+df['writing score']
df['average score'] = df['total score']/3
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    total score  average score
# 0          218      72.666667
# 1          247      82.333333
# 2          278      92.666667
# ...

# %%
# explore the dataset
print("Categories in 'gender' variable: ",df['gender'].unique())
print('------------------------------------------------------------------------------------------------------------')
print("Categories in 'race/ethnicity' variable: ",df['race/ethnicity'].unique())
print('------------------------------------------------------------------------------------------------------------')
print("Categories in 'parental level of education' variable: ",df['parental level of education'].unique())
print('------------------------------------------------------------------------------------------------------------')
print("Categories in 'lunch' variable: ",df['lunch'].unique())
print('------------------------------------------------------------------------------------------------------------')
print("Categories in 'test preparation course' variable: ",df['test preparation course'].unique())
# Out:
# Categories in 'gender' variable:  ['female' 'male']
# ------------------------------------------------------------------------------------------------------------
# Categories in 'race/ethnicity' variable:  ['group B' 'group C' 'group A' 'group D' 'group E']
# ------------------------------------------------------------------------------------------------------------
# Categories in 'parental level of education' variable:  ["bachelor's degree" 'some college' "master's degree" "associate's degree"
#  'high school' 'some high school']
# ------------------------------------------------------------------------------------------------------------
# Categories in 'lunch' variable:  ['standard' 'free/reduced']
# ------------------------------------------------------------------------------------------------------------
# Categories in 'test preparation course' variable:  ['none' 'completed']

# %%
# Lets start with plotting graphs (Visualization)

# %%
# distribution of math score
sns.countplot(x=df['math score'])
plt.title('Math Score',fontsize = 20)
plt.show()

# %%
# distribution of reading score
sns.countplot(x=df['reading score'])
plt.title('Reading Score',fontsize=20)
plt.show()

# %%
# distribution of writing score
sns.countplot(x=df['writing score'])
plt.title('Writing Score',fontsize=20)
plt.show()

# %%
# maximum score of students in all three subjects

plt.figure(figsize=(10,4))
plt.subplot(1,4,1)
plt.title('MATH SCORES') 
sns.violinplot(y='math score',data=df,color='red',linewidth=3)
plt.subplot(1,4,2) 
plt.title('READING SCORES') 
sns.violinplot(y='reading score',data=df,color='green',linewidth=3)
plt.subplot(1,4,3)
plt.title('WRITING SCORES')
sns.violinplot(y='writing score',data=df,color='blue',linewidth=3)

plt.show()

# %% [markdown]
# ##### from above three plots, most of the students have scored 60-80 in all three subjects.

# %%
# Lets see remaining columns using pie plot

# %%
plt.figure(figsize=(20,10))
plt.subplot(2,3,1)
plt.title('Gender')
df['gender'].value_counts().plot.pie(autopct='%.2f%%')
plt.axis('off')

plt.subplot(2,3,2)
plt.title('Race/Ethnicity')
df['race/ethnicity'].value_counts().plot.pie(autopct='%.2f%%')
plt.axis('off')

plt.subplot(2,3,3)
plt.title('Parental Level of Education')
df['parental level of education'].value_counts().plot.pie(autopct='%.2f%%')
plt.axis('off')

plt.subplot(2,3,4)
plt.title('Lunch')
df['lunch'].value_counts().plot.pie(autopct='%.2f%%')
plt.axis('off')

plt.subplot(2,3,5)
plt.title('Test Course')
df['test preparation course'].value_counts().plot.pie(autopct='%.2f%%')
plt.axis('off')

plt.show()

# %%
# 1. both gender is almost equal.
# 2. number of students in higher in group C.
# 3. number of students whose parental education in "Some College" is closely followed by "Associate's Degree".
# 4. students having standard lunch is greater.
# 5. test course taken by none students is greater.

# %% [markdown]
# #### Feature Wise Visualization

# %%
## 1. Gender Column

# %%
# How is distribution of Gender ?

fig,axs=plt.subplots(1,2,figsize=(8,4))
sns.countplot(data=df,x=df['gender'],ax=axs[0])
for container in axs[0].containers:
    axs[0].bar_label(container)

plt.pie(x=df['gender'].value_counts(),labels=['Male','Female'],autopct='%.2f%%')
plt.show()

# %% [markdown]
# ##### Gender has apprx balanced data.

# %%
# Is gender has any impact on student's performance ?

gender_group = df.groupby('gender').mean()
gender_group
# Out:
#         math score  reading score  writing score  total score  average score
# gender
# female   63.633205      72.608108      72.467181   208.708494      69.569498
# male     68.728216      65.473029      63.311203   197.512448      65.837483

# %%
plt.figure(figsize=(8,6))

X = ['Total Average','Math Average']

female_scores = [gender_group['average score'][0],gender_group['math score'][0]]
male_scores = [gender_group['average score'][1],gender_group['math score'][1]]
x_axis = np.arange(len(X))
plt.bar(x_axis-0.2,male_scores,0.4,label='Male')
plt.bar(x_axis+0.2,female_scores,0.4,label='Female')

plt.xticks(x_axis,X)
plt.ylabel('Marks')
plt.legend()
plt.show()

# %% [markdown]
# ##### In total, females have better score than males whereas Males scored higher in math.

# %%
## 2. Race/Ethnicity Column

# %%
# How is group wise distribution ?

fig,axs=plt.subplots(1,2,figsize=(8,4))
sns.countplot(data=df,x=df['race/ethnicity'],ax=axs[0])
for container in axs[0].containers:
    axs[0].bar_label(container)

plt.pie(x=df['race/ethnicity'].value_counts(),labels=df['race/ethnicity'].value_counts().index,autopct='%.2f%%')
plt.show()

# %% [markdown]
# ##### most of the students belonging from group C and group D.
# ##### group A has the lowest number of students

# %%
# Is race/ethnicity has any impact on student's performance ?

race_group = df.groupby('race/ethnicity')

f,ax=plt.subplots(1,3,figsize=(20,8))
sns.barplot(x=race_group['math score'].mean().index,y=race_group['math score'].mean().values,ax=ax[0])
ax[0].set_title('Math Score')

for container in ax[0].containers:
    ax[0].bar_label(container)

sns.barplot(x=race_group['reading score'].mean().index,y=race_group['reading score'].mean().values,ax=ax[1])
ax[1].set_title('Reading Score')

for container in ax[1].containers:
    ax[1].bar_label(container)

sns.barplot(x=race_group['writing score'].mean().index,y=race_group['writing score'].mean().values,ax=ax[2])
ax[2].set_title('Writing Score')

for container in ax[2].containers:
    ax[2].bar_label(container)

plt.show()

# %% [markdown]
# ##### group E students have scored highest marks while group A scored lowest.

# %%
## 3. Parental Level of Education Column

# %%
# What is educational background of student's parent ?

plt.figure(figsize=(13,7))
sns.countplot(data=df,x=df['parental level of education'])
plt.title('Comparison of Parental Education')
plt.xlabel('degree')
plt.ylabel('count')
plt.show()

# %% [markdown]
# ##### largest number of parents are from 'some college'.

# %%
# Is parental education has any impact on student's performance ?

df.groupby('parental level of education').agg('mean').plot(kind='barh')
plt.legend(bbox_to_anchor=(1.05,1))
plt.show()

# %% [markdown]
# ##### parents possess master's and bachelor's degree are higher than others.

# %%
## 4. Lunch Column

# %%
# Which type of lunch is most common among students ?

plt.figure(figsize=(4,3))
sns.countplot(data=df,x=df['lunch'])
plt.title('Comparison of types of Lunch')
plt.xlabel('types of lunch')
plt.ylabel('count')
plt.show()

# %% [markdown]
# ##### students being served standard lunch was more than free/reduced lunch.

# %%
# What is the effect of lunch type on test results ?

f,ax=plt.subplots(1,2,figsize=(20,8))
sns.countplot(x=df['parental level of education'],data=df,hue='test preparation course',ax=ax[0])
ax[0].set_title('Students vs Test Results')
for container in ax[0].containers:
    ax[0].bar_label(container)

sns.countplot(x=df['parental level of education'],data=df,hue='lunch',ax=ax[1])
for container in ax[1].containers:
    ax[0].bar_label(container)

plt.show()

# %% [markdown]
# ##### students who get standard lunch perform better than free/reduced lunch.

# %%
# checking outliers

plt.subplots(1,3,figsize=(9,3))
plt.subplot(1,4,1)
sns.boxplot(df['math score'],color='grey')
plt.subplot(1,4,2)
sns.boxplot(df['reading score'],color='red')
plt.subplot(1,4,3)
sns.boxplot(df['writing score'],color='yellow')

plt.show()
